# %% [markdown]
# ## PROJECT - Classifying Diabetes Risk Using Machine Learning On BRFSS 2024 Data

# %% [markdown]
# # Importing the data RAW DATA

# %% [markdown]
# ### *Data Source* – BRFSS 2024 (CDC)
#
# The dataset was downloaded from the official CDC BRFSS repository:
# [BRFSS 2024 Survey Data (XPT Format) one click to download 📩 here](https://www.cdc.gov/brfss/annual_data/2024/files/LLCP2024XPT.zip)
#
# The 2024 Behavioral Risk Factor Surveillance System (BRFSS) dataset was downloaded from the CDC’s official public health data portal.
# The file was provided in SAS XPT (transport) format, which is commonly used for sharing data between SAS, SPSS, and STATA. The dataset contains 345 variables and includes combined landline and cellphone survey responses collected across 49 U.S. states, D.C., Guam, Puerto Rico, and the U.S. Virgin Islands. (Tennessee data is excluded due to insufficient sample size.)

# %% [markdown]
#     This format is used by SAS/SPSS/STATA, not directly by Python.
#
#     So we converted it into a normal CSV file to easily work with it in Pandas.

# %% [markdown]
# # You can refer the CODEBOOK for this data as it contains each variable informaetion and thier meanings
# READ AND DOWNLOAD VARIABLE INFO: [CODEBOOK](https://www.cdc.gov/brfss/annual_data/2024/pdf/Overview_2024-508.pdf)

# %%
import pandas as pd

df = pd.read_sas(r"C:\Users\Junaid\Downloads\LLCP2024XPT\LLCP2024.XPT", format="xport")

# %% [markdown]
# #### Converted raw survey transport files to CSV  and saved as BRFSS_2024.csv now we are going to open in another NOTEBOOK!

# %%
df.to_csv("BRFSS_2024.csv", index=False)

# %%
# done acceses this later
